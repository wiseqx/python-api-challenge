# %% [markdown]
# # Import libraries

# %%
# Dependencies
import matplotlib.pyplot as plt
import requests
import pandas as pd
from config import api_key
import json
import numpy as np
from citipy import citipy
from scipy.stats import linregress
import datetime

# %% [markdown]
# # Generate random list for latitudes and longitudes

# %%
#Generate random list for latitudes and longitudes
np.random.seed(18)
latitude=[lat for lat in np.random.randint(-90,90,2000)]
longitude=[lon for lon in np.random.randint(-180,180,2000)]
latitude_and_Longitude = tuple(zip(latitude,longitude))

# %% [markdown]
# # Find Nearest City

# %%
#use citipy library to find the nearest city for all latitudes and longitudes
cities = []
countries = []

for lat, lon in latitude_and_Longitude:
    city = citipy.nearest_city(lat,lon)
    city_name = city.city_name
    cities.append(city_name)
    countries.append(city.country_code)

# %% [markdown]
# ## Generate Dataframe for all information

# %%
city_df = pd.DataFrame({'City': cities, 'Country': countries})
city_df = city_df.drop_duplicates(subset=['City'],keep='first')
city_df['Date']=""
city_df['Latitude'] = ''
city_df['Longitude'] = ''
city_df['Max Temperature (F)'] = ''
city_df['Humidity (%)'] = ''
city_df['Cloudiness (%)'] = ''
city_df['Wind Speed (mph)'] = ''
city_df.head()
# Out:
#               City Country Date Latitude Longitude Max Temperature (F)  \
# 0  arraial do cabo      br
# 1        taolanaro      mg
# 2            mrirt      ma
# 3           koumac      nc
# 4      yellowknife      ca
#
#   Humidity (%) Cloudiness (%) Wind Speed (mph)
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Perform Openweathermap API calls

# %%
for index, row in city_df.iterrows():
    city = row['City']
    country_code = row['Country']
    query_url = "http://api.openweathermap.org/data/2.5/weather?q=" + \
                city + ',' + country_code + '&units=' + "imperial" + '&APPID=' + api_key
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()

    try:
        print(f"Retrieving Row {index}, City Name: {city}.")
        city_df.loc[index,'Date']=datetime.datetime.fromtimestamp(weather_json['dt'])
        city_df.loc[index,'Latitude']=weather_json['coord']['lat']
        city_df.loc[index,'Longitude']=weather_json['coord']['lon']
        city_df.loc[index,'Max Temperature (F)']=weather_json['main']['temp_max']
        city_df.loc[index, 'Humidity (%)']=weather_json['main']['humidity']
        city_df.loc[index, 'Cloudiness (%)']=weather_json['clouds']['all']
        city_df.loc[index, 'Wind Speed (mph)']=weather_json['wind']['speed']
        
    
    except:
        print(f"Oops, Record {index} city: {city} not found! ")

print("-----------------------------")        
print("Data Retrieval Complete!")
# Out:
# Retrieving Row 0, City Name: arraial do cabo.
# Retrieving Row 1, City Name: taolanaro.
# Oops, Record 1 city: taolanaro not found!
# Retrieving Row 2, City Name: mrirt.
# Oops, Record 2 city: mrirt not found!
# Retrieving Row 3, City Name: koumac.
# Retrieving Row 4, City Name: yellowknife.
# Retrieving Row 5, City Name: mehamn.
# Retrieving Row 6, City Name: vao.
# Retrieving Row 7, City Name: bluff.
# Retrieving Row 8, City Name: ossora.
# Retrieving Row 9, City Name: provideniya.
# Retrieving Row 10, City Name: port hardy.
# Retrieving Row 11, City Name: hithadhoo.
# Retrieving Row 12, City Name: kapaa.
# Retrieving Row 13, City Name: leninskoye.
# Retrieving Row 14, City Name: bengkulu.
# Retrieving Row 15, City Name: khatanga.
# Retrieving Row 16, City Name: rikitea.
# Retrieving Row 17, City Name: miguel hidalgo.
# Retrieving Row 18, City Name: patacamaya.
# Retrieving Row 19, City Name: muros.
# Retrieving Row 20, City Name: cape town.
# Retrieving Row 22, City Name: gamba.
# Retrieving Row 23, City Name: hacienda heights.
# Retrieving Row 24, City Name: ushuaia.
# Retrieving Row 25, City Name: partyzany.
# Retrieving Row 26, City Name: magadan.
# Retrieving Row 27, City Name: werda.
# Retrieving Row 28, City Name: touros.
# Retrieving Row 29, City Name: nikolskoye.
# Retrieving Row 30, City Name: kazalinsk.
# Oops, Record 30 city: kazalinsk not found!
# Retrieving Row 31, City Name: new norfolk.
# Retrieving Row 32, City Name: geraldton.
# Retrieving Row 34, City Name: barrow.
# Retrieving Row 35, City Name: attawapiskat.
# Oops, Record 35 city: attawapiskat not found!
# Retrieving Row 36, City Name: jinzhou.
# Retrieving Row 37, City Name: talnakh.
# Retrieving Row 38, City Name: mataura.
# Oops, Record 38 city: mataura not found!
# Retrieving Row 39, City Name: kaitangata.
# Retrieving Row 40, City Name: tombouctou.
# Retrieving Row 41, City Name: atuona.
# Retrieving Row 42, City Name: brae.
# Retrieving Row 44, City Name: punta arenas.
# Retrieving Row 45, City Name: kismayo.
# Retrieving Row 46, City Name: pisco.
# Retrieving Row 48, City Name: sinnamary.
# Retrieving Row 49, City Name: samusu.
# Oops, Record 49 city: samusu not found!
# Retrieving Row 50, City Name: keita.
# Retrieving Row 52, City Name: hermanus.
# Retrieving Row 53, City Name: bredasdorp.
# Retrieving Row 54, City Name: aktas.
# Retrieving Row 55, City Name: dossor.
# Retrieving Row 58, City Name: belushya guba.
# Oops, Record 58 city: belushya guba not found!
# Retrieving Row 59, City Name: nizhneyansk.
# Oops, Record 59 city: nizhneyansk not found!
# Retrieving Row 62, City Name: jhikargachha.
# Oops, Record 62 city: jhikargachha not found!
# Retrieving Row 65, City Name: saint-philippe.
# Retrieving Row 66, City Name: picota.
# Retrieving Row 67, City Name: necochea.
# Retrieving Row 68, City Name: butaritari.
# Retrieving Row 69, City Name: vaitupu.
# Oops, Record 69 city: vaitupu not found!
# Retrieving Row 71, City Name: iqaluit.
# Retrieving Row 73, City Name: ratisbon.
# Oops, Record 73 city: ratisbon not found!
# Retrieving Row 74, City Name: cherskiy.
# Retrieving Row 75, City Name: khislavichi.
# Retrieving Row 76, City Name: guerrero negro.
# Retrieving Row 77, City Name: tiksi.
# Retrieving Row 79, City Name: varhaug.
# Retrieving Row 80, City Name: constitucion.
# Retrieving Row 81, City Name: melfi.
# Retrieving Row 82, City Name: hamilton.
# Retrieving Row 83, City Name: pochutla.
# Retrieving Row 86, City Name: malwan.
# Oops, Record 86 city: malwan not found!
# Retrieving Row 87, City Name: ichinoseki.
# Retrieving Row 88, City Name: cuiluan.
# Retrieving Row 89, City Name: hobart.
# Retrieving Row 91, City Name: bataipora.
# Retrieving Row 92, City Name: ginda.
# Oops, Record 92 city: ginda not found!
# Retrieving Row 94, City Name: broome.
# Retrieving Row 96, City Name: ponta do sol.
# Retrieving Row 97, City Name: busselton.
# Retrieving Row 98, City Name: gorontalo.
# Retrieving Row 101, City Name: faanui.
# Retrieving Row 103, City Name: freilassing.
# Retrieving Row 104, City Name: sola.
# Retrieving Row 106, City Name: albany.
# Retrieving Row 107, City Name: kupang.
# Retrieving Row 108, City Name: lorengau.
# Retrieving Row 110, City Name: hilo.
# Retrieving Row 111, City Name: saleaula.
# Oops, Record 111 city: saleaula not found!
# Retrieving Row 112, City Name: barentsburg.
# Oops, Record 112 city: barentsburg not found!
# Retrieving Row 113, City Name: avera.
# Oops, Record 113 city: avera not found!
# Retrieving Row 114, City Name: tuatapere.
# Retrieving Row 115, City Name: schenectady.
# Retrieving Row 117, City Name: chapais.
# Retrieving Row 118, City Name: jamestown.
# Retrieving Row 119, City Name: karratha.
# Retrieving Row 121, City Name: lima.
# Retrieving Row 122, City Name: dongsheng.
# Retrieving Row 123, City Name: college.
# Retrieving Row 126, City Name: tigil.
# Retrieving Row 128, City Name: port blair.
# Retrieving Row 129, City Name: vaini.
# Retrieving Row 131, City Name: makakilo city.
# Retrieving Row 132, City Name: amga.
# Retrieving Row 134, City Name: pacific grove.
# Retrieving Row 135, City Name: asau.
# Oops, Record 135 city: asau not found!
# Retrieving Row 136, City Name: satipo.
# Retrieving Row 137, City Name: sorvag.
# Oops, Record 137 city: sorvag not found!
# Retrieving Row 138, City Name: qaanaaq.
# Retrieving Row 139, City Name: bambous virieux.
# Retrieving Row 142, City Name: khorixas.
# Retrieving Row 144, City Name: puerto ayora.
# Retrieving Row 146, City Name: chinique.
# Retrieving Row 147, City Name: cabo san lucas.
# Retrieving Row 148, City Name: zhezkazgan.
# Retrieving Row 150, City Name: longlac.
# Oops, Record 150 city: longlac not found!
# Retrieving Row 152, City Name: oksfjord.
# Retrieving Row 153, City Name: castro.
# Retrieving Row 155, City Name: ixtapa.
# Retrieving Row 156, City Name: jumla.
# Retrieving Row 157, City Name: vila.
# Oops, Record 157 city: vila not found!
# Retrieving Row 161, City Name: caravelas.
# Retrieving Row 163, City Name: airai.
# Oops, Record 163 city: airai not found!
# Retrieving Row 166, City Name: taoudenni.
# Retrieving Row 167, City Name: buala.
# Retrieving Row 168, City Name: svetlogorsk.
# Retrieving Row 169, City Name: grand gaube.
# Retrieving Row 172, City Name: suar.
# Retrieving Row 173, City Name: komsomolskiy.
# Retrieving Row 177, City Name: dikson.
# Retrieving Row 179, City Name: adrar.
# Retrieving Row 180, City Name: requena.
# Oops, Record 180 city: requena not found!
# Retrieving Row 181, City Name: praya.
# Retrieving Row 182, City Name: vestmannaeyjar.
# Retrieving Row 183, City Name: illoqqortoormiut.
# Oops, Record 183 city: illoqqortoormiut not found!
# Retrieving Row 184, City Name: araouane.
# Retrieving Row 185, City Name: flores.
# Retrieving Row 186, City Name: miandrivazo.
# Retrieving Row 187, City Name: sorong.
# Retrieving Row 191, City Name: huarmey.
# Retrieving Row 192, City Name: aasiaat.
# Retrieving Row 193, City Name: coquimbo.
# Retrieving Row 196, City Name: pitimbu.
# Retrieving Row 197, City Name: grand island.
# Retrieving Row 198, City Name: san juan.
# Retrieving Row 199, City Name: nanortalik.
# Retrieving Row 200, City Name: prado.
# Retrieving Row 201, City Name: lompoc.
# Retrieving Row 202, City Name: tawkar.
# Oops, Record 202 city: tawkar not found!
# Retrieving Row 203, City Name: bethel.
# Retrieving Row 207, City Name: yueyang.
# Retrieving Row 209, City Name: san quintin.
# Retrieving Row 210, City Name: lobito.
# Retrieving Row 211, City Name: alyangula.
# Retrieving Row 214, City Name: havoysund.
# Retrieving Row 221, City Name: doha.
# Retrieving Row 222, City Name: bachaquero.
# Retrieving Row 224, City Name: beckley.
# Retrieving Row 225, City Name: kawana waters.
# Oops, Record 225 city: kawana waters not found!
# Retrieving Row 227, City Name: pontianak.
# Retrieving Row 228, City Name: cayenne.
# Retrieving Row 229, City Name: strelka.
# Retrieving Row 230, City Name: port alfred.
# Retrieving Row 231, City Name: massena.
# Retrieving Row 235, City Name: ketchikan.
# Retrieving Row 236, City Name: lagdo.
# Retrieving Row 237, City Name: urumqi.
# Retrieving Row 238, City Name: acapulco.
# Retrieving Row 239, City Name: port lincoln.
# Retrieving Row 242, City Name: panjab.
# Retrieving Row 245, City Name: hervey bay.
# Retrieving Row 246, City Name: masterton.
# Retrieving Row 252, City Name: saint george.
# Retrieving Row 256, City Name: pueblo nuevo.
# Retrieving Row 257, City Name: chimoio.
# Retrieving Row 258, City Name: benguela.
# Retrieving Row 259, City Name: ribeira grande.
# Retrieving Row 260, City Name: copiapo.
# Retrieving Row 261, City Name: lebu.
# Retrieving Row 262, City Name: elk grove village.
# Retrieving Row 263, City Name: paita.
# Retrieving Row 266, City Name: upernavik.
# Retrieving Row 268, City Name: montanha.
# Retrieving Row 270, City Name: tual.
# Retrieving Row 272, City Name: brindisi.
# Retrieving Row 274, City Name: limbang.
# Retrieving Row 278, City Name: tasiilaq.
# Retrieving Row 280, City Name: carnarvon.
# Retrieving Row 281, City Name: nueve de julio.
# Retrieving Row 282, City Name: hofn.
# Retrieving Row 283, City Name: nioro.
# Oops, Record 283 city: nioro not found!
# Retrieving Row 287, City Name: vardo.
# Retrieving Row 288, City Name: tazovskiy.
# Retrieving Row 289, City Name: itapeva.
# Retrieving Row 290, City Name: tumannyy.
# Oops, Record 290 city: tumannyy not found!
# Retrieving Row 292, City Name: katherine.
# Retrieving Row 294, City Name: kavaratti.
# Retrieving Row 295, City Name: fernandez.
# Oops, Record 295 city: fernandez not found!
# Retrieving Row 298, City Name: saldanha.
# Retrieving Row 300, City Name: lagunas.
# Retrieving Row 301, City Name: daxian.
# Oops, Record 301 city: daxian not found!
# Retrieving Row 302, City Name: avarua.
# Retrieving Row 305, City Name: ahipara.
# Retrieving Row 310, City Name: hami.
# Retrieving Row 311, City Name: tecoanapa.
# Retrieving Row 312, City Name: marsh harbour.
# Retrieving Row 313, City Name: puerto leguizamo.
# Retrieving Row 314, City Name: esperance.
# Retrieving Row 316, City Name: chokurdakh.
# Retrieving Row 320, City Name: stromness.
# Retrieving Row 322, City Name: mahebourg.
# Retrieving Row 324, City Name: tura.
# Retrieving Row 327, City Name: tabarqah.
# Oops, Record 327 city: tabarqah not found!
# Retrieving Row 329, City Name: bria.
# Retrieving Row 331, City Name: maniwaki.
# Retrieving Row 333, City Name: baykit.
# Retrieving Row 336, City Name: itoman.
# Retrieving Row 340, City Name: opuwo.
# Retrieving Row 341, City Name: diamantino.
# Retrieving Row 342, City Name: yulara.
# Retrieving Row 343, City Name: ilulissat.
# Retrieving Row 350, City Name: kirakira.
# Retrieving Row 352, City Name: fare.
# Retrieving Row 353, City Name: grand river south east.
# Oops, Record 353 city: grand river south east not found!
# Retrieving Row 355, City Name: matara.
# Retrieving Row 356, City Name: dandong.
# Retrieving Row 359, City Name: pevek.
# Retrieving Row 360, City Name: vostok.
# Retrieving Row 364, City Name: verkhovyna.
# Retrieving Row 366, City Name: port elizabeth.
# Retrieving Row 367, City Name: beloha.
# Retrieving Row 369, City Name: koutsouras.
# Retrieving Row 370, City Name: tiassale.
# Retrieving Row 376, City Name: truro.
# Retrieving Row 380, City Name: skjervoy.
# Retrieving Row 381, City Name: sao filipe.
# Retrieving Row 383, City Name: thompson.
# Retrieving Row 389, City Name: aykhal.
# Retrieving Row 390, City Name: oranjemund.
# Retrieving Row 391, City Name: kampong chhnang.
# Retrieving Row 393, City Name: kahului.
# Retrieving Row 397, City Name: machala.
# Retrieving Row 398, City Name: abeche.
# Retrieving Row 401, City Name: tortoli.
# Retrieving Row 402, City Name: yerofey pavlovich.
# Retrieving Row 403, City Name: jalu.
# Retrieving Row 404, City Name: torbay.
# Retrieving Row 405, City Name: lata.
# Oops, Record 405 city: lata not found!
# Retrieving Row 407, City Name: catamarca.
# Retrieving Row 413, City Name: te anau.
# Retrieving Row 416, City Name: kiunga.
# Retrieving Row 417, City Name: byron bay.
# Retrieving Row 421, City Name: dawei.
# Retrieving Row 425, City Name: namibe.
# Retrieving Row 428, City Name: tuktoyaktuk.
# Retrieving Row 432, City Name: santa vitoria do palmar.
# Retrieving Row 433, City Name: vila velha.
# Retrieving Row 437, City Name: tucuma.
# Retrieving Row 439, City Name: mudbidri.
# Retrieving Row 443, City Name: great falls.
# Retrieving Row 444, City Name: korla.
# Retrieving Row 448, City Name: ajdabiya.
# Retrieving Row 451, City Name: gat.
# Oops, Record 451 city: gat not found!
# Retrieving Row 453, City Name: bodden town.
# Retrieving Row 455, City Name: sobolevo.
# Retrieving Row 457, City Name: okhotsk.
# Retrieving Row 459, City Name: teya.
# Retrieving Row 460, City Name: southbridge.
# Retrieving Row 461, City Name: leningradskiy.
# Retrieving Row 464, City Name: amderma.
# Oops, Record 464 city: amderma not found!
# Retrieving Row 467, City Name: selma.
# Retrieving Row 468, City Name: cap malheureux.
# Retrieving Row 472, City Name: ostrovnoy.
# Retrieving Row 473, City Name: jaicos.
# Retrieving Row 474, City Name: thinadhoo.
# Retrieving Row 475, City Name: kiruna.
# Retrieving Row 477, City Name: pousat.
# Oops, Record 477 city: pousat not found!
# Retrieving Row 479, City Name: elko.
# Retrieving Row 480, City Name: cidreira.
# Retrieving Row 482, City Name: faya.
# Oops, Record 482 city: faya not found!
# Retrieving Row 483, City Name: dzhusaly.
# Oops, Record 483 city: dzhusaly not found!
# Retrieving Row 486, City Name: kalyazin.
# Retrieving Row 488, City Name: katsuura.
# Retrieving Row 490, City Name: hasaki.
# Retrieving Row 491, City Name: mount gambier.
# Retrieving Row 493, City Name: teguise.
# Retrieving Row 494, City Name: prince george.
# Retrieving Row 495, City Name: comodoro rivadavia.
# Retrieving Row 497, City Name: severo-kurilsk.
# Retrieving Row 502, City Name: dolbeau.
# Oops, Record 502 city: dolbeau not found!
# Retrieving Row 504, City Name: paamiut.
# Retrieving Row 506, City Name: vestmanna.
# Retrieving Row 508, City Name: boyolangu.
# Retrieving Row 510, City Name: bilibino.
# Retrieving Row 513, City Name: grindavik.
# Retrieving Row 515, City Name: punto fijo.
# Retrieving Row 518, City Name: ballina.
# Retrieving Row 520, City Name: east london.
# Retrieving Row 523, City Name: bathsheba.
# Retrieving Row 525, City Name: jacmel.
# Retrieving Row 529, City Name: el real de santa maria.
# Retrieving Row 530, City Name: san patricio.
# Retrieving Row 532, City Name: khandyga.
# Retrieving Row 534, City Name: narsaq.
# Retrieving Row 537, City Name: obo.
# Retrieving Row 538, City Name: tarko-sale.
# Retrieving Row 539, City Name: lourdes.
# Retrieving Row 544, City Name: codrington.
# Oops, Record 544 city: codrington not found!
# Retrieving Row 549, City Name: maningrida.
# Retrieving Row 552, City Name: ambon.
# Retrieving Row 554, City Name: road town.
# Retrieving Row 558, City Name: batagay-alyta.
# Retrieving Row 559, City Name: biltine.
# Retrieving Row 563, City Name: ragama.
# Retrieving Row 564, City Name: chipata.
# Retrieving Row 566, City Name: la ronge.
# Retrieving Row 567, City Name: sibolga.
# Retrieving Row 573, City Name: chuy.
# Retrieving Row 576, City Name: ancud.
# Retrieving Row 577, City Name: yirol.
# Oops, Record 577 city: yirol not found!
# Retrieving Row 580, City Name: cockburn town.
# Retrieving Row 581, City Name: aguimes.
# Retrieving Row 582, City Name: meybod.
# Retrieving Row 585, City Name: warrington.
# Retrieving Row 588, City Name: fairbanks.
# Retrieving Row 590, City Name: ugoofaaru.
# Retrieving Row 592, City Name: solovetskiy.
# Oops, Record 592 city: solovetskiy not found!
# Retrieving Row 595, City Name: tomatlan.
# Retrieving Row 597, City Name: maghama.
# Oops, Record 597 city: maghama not found!
# Retrieving Row 598, City Name: teknaf.
# Retrieving Row 603, City Name: xifeng.
# Retrieving Row 604, City Name: marzuq.
# Oops, Record 604 city: marzuq not found!
# Retrieving Row 606, City Name: el faiyum.
# Oops, Record 606 city: el faiyum not found!
# Retrieving Row 608, City Name: taldan.
# Retrieving Row 611, City Name: guantanamo.
# Retrieving Row 617, City Name: constantine.
# Retrieving Row 622, City Name: tucumcari.
# Retrieving Row 623, City Name: san rafael.
# Retrieving Row 624, City Name: tilichiki.
# Retrieving Row 632, City Name: tsihombe.
# Oops, Record 632 city: tsihombe not found!
# Retrieving Row 633, City Name: lewistown.
# Retrieving Row 634, City Name: agadez.
# Retrieving Row 636, City Name: imbituba.
# Retrieving Row 639, City Name: kadykchan.
# Oops, Record 639 city: kadykchan not found!
# Retrieving Row 640, City Name: solnechnyy.
# Retrieving Row 642, City Name: mayor pablo lagerenza.
# Retrieving Row 645, City Name: jiwani.
# Retrieving Row 651, City Name: ivybridge.
# Retrieving Row 652, City Name: cukai.
# Retrieving Row 655, City Name: mar del plata.
# Retrieving Row 657, City Name: pangnirtung.
# Retrieving Row 661, City Name: morgan city.
# Retrieving Row 662, City Name: isangel.
# Retrieving Row 667, City Name: norman wells.
# Retrieving Row 668, City Name: flinders.
# Retrieving Row 671, City Name: westpunt.
# Oops, Record 671 city: westpunt not found!
# Retrieving Row 672, City Name: margate.
# Retrieving Row 673, City Name: palabuhanratu.
# Oops, Record 673 city: palabuhanratu not found!
# Retrieving Row 674, City Name: vagamo.
# Retrieving Row 676, City Name: murgab.
# Retrieving Row 677, City Name: kodiak.
# Retrieving Row 681, City Name: camalu.
# Retrieving Row 683, City Name: kalmunai.
# Retrieving Row 684, City Name: mahibadhoo.
# Retrieving Row 686, City Name: gorom-gorom.
# Retrieving Row 690, City Name: mabaruma.
# Retrieving Row 693, City Name: riyadh.
# Retrieving Row 694, City Name: muscatine.
# Retrieving Row 699, City Name: tyup.
# Retrieving Row 701, City Name: lugazi.
# Retrieving Row 703, City Name: lazaro cardenas.
# Retrieving Row 711, City Name: benjamin hill.
# Retrieving Row 713, City Name: hurghada.
# Retrieving Row 715, City Name: dunmore east.
# Retrieving Row 717, City Name: sioux lookout.
# Retrieving Row 719, City Name: paralimni.
# Retrieving Row 722, City Name: bargal.
# Oops, Record 722 city: bargal not found!
# Retrieving Row 725, City Name: lufilufi.
# Retrieving Row 726, City Name: papillion.
# Retrieving Row 731, City Name: den chai.
# Retrieving Row 736, City Name: nelson bay.
# Retrieving Row 740, City Name: angul.
# Retrieving Row 744, City Name: samalaeulu.
# Oops, Record 744 city: samalaeulu not found!
# Retrieving Row 745, City Name: rio blanco.
# Retrieving Row 746, City Name: sinop.
# Retrieving Row 747, City Name: potiskum.
# Retrieving Row 748, City Name: slave lake.
# Retrieving Row 749, City Name: iquique.
# Retrieving Row 753, City Name: zheleznodorozhnyy.
# Retrieving Row 754, City Name: petropavlovsk-kamchatskiy.
# Retrieving Row 755, City Name: peleduy.
# Retrieving Row 756, City Name: bambanglipuro.
# Retrieving Row 758, City Name: havelock.
# Retrieving Row 767, City Name: nara.
# Retrieving Row 770, City Name: socorro.
# Retrieving Row 775, City Name: sakata.
# Retrieving Row 781, City Name: cheltenham.
# Retrieving Row 782, City Name: aksarka.
# Retrieving Row 784, City Name: valparaiso.
# Retrieving Row 785, City Name: tabiauea.
# Oops, Record 785 city: tabiauea not found!
# Retrieving Row 787, City Name: saskylakh.
# Retrieving Row 790, City Name: pitiquito.
# Retrieving Row 793, City Name: akdepe.
# Retrieving Row 797, City Name: kem.
# Retrieving Row 798, City Name: srikakulam.
# Retrieving Row 800, City Name: kaeo.
# Retrieving Row 801, City Name: longyearbyen.
# Retrieving Row 804, City Name: port-gentil.
# Retrieving Row 806, City Name: darnah.
# Retrieving Row 807, City Name: marica.
# Retrieving Row 815, City Name: naze.
# Retrieving Row 816, City Name: pemba.
# Retrieving Row 817, City Name: dudinka.
# Retrieving Row 820, City Name: dingle.
# Retrieving Row 825, City Name: governador valadares.
# Retrieving Row 826, City Name: maraa.
# Retrieving Row 830, City Name: saint anthony.
# Oops, Record 830 city: saint anthony not found!
# Retrieving Row 832, City Name: biak.
# Retrieving Row 835, City Name: ayolas.
# Retrieving Row 838, City Name: nanakuli.
# Retrieving Row 840, City Name: birecik.
# Retrieving Row 843, City Name: general roca.
# Retrieving Row 854, City Name: altay.
# Retrieving Row 856, City Name: athabasca.
# Retrieving Row 860, City Name: cradock.
# Retrieving Row 864, City Name: corrales.
# Retrieving Row 865, City Name: tautira.
# Retrieving Row 867, City Name: kosjeric.
# Retrieving Row 869, City Name: muravlenko.
# Retrieving Row 870, City Name: kununurra.
# Retrieving Row 872, City Name: lasa.
# Oops, Record 872 city: lasa not found!
# Retrieving Row 878, City Name: itaqui.
# Retrieving Row 881, City Name: grafton.
# Retrieving Row 883, City Name: baherden.
# Retrieving Row 886, City Name: bose.
# Oops, Record 886 city: bose not found!
# Retrieving Row 888, City Name: susehri.
# Retrieving Row 891, City Name: aconibe.
# Retrieving Row 895, City Name: yar-sale.
# Retrieving Row 896, City Name: artyk.
# Oops, Record 896 city: artyk not found!
# Retrieving Row 897, City Name: abu samrah.
# Oops, Record 897 city: abu samrah not found!
# Retrieving Row 900, City Name: petukhovo.
# Retrieving Row 901, City Name: champerico.
# Retrieving Row 907, City Name: dali.
# Retrieving Row 913, City Name: miraflores.
# Retrieving Row 917, City Name: yantal.
# Retrieving Row 919, City Name: kamiiso.
# Retrieving Row 921, City Name: amapa.
# Retrieving Row 925, City Name: bandarbeyla.
# Retrieving Row 927, City Name: kuala kedah.
# Retrieving Row 930, City Name: clyde river.
# Retrieving Row 931, City Name: belmonte.
# Retrieving Row 934, City Name: itarema.
# Retrieving Row 935, City Name: olafsvik.
# Retrieving Row 938, City Name: springbok.
# Retrieving Row 940, City Name: pacifica.
# Retrieving Row 944, City Name: louisbourg.
# Oops, Record 944 city: louisbourg not found!
# Retrieving Row 946, City Name: watrous.
# Retrieving Row 957, City Name: antalaha.
# Retrieving Row 959, City Name: bolshaya chernigovka.
# Oops, Record 959 city: bolshaya chernigovka not found!
# Retrieving Row 962, City Name: sentyabrskiy.
# Oops, Record 962 city: sentyabrskiy not found!
# Retrieving Row 969, City Name: boralday.
# Retrieving Row 976, City Name: burlington.
# Retrieving Row 977, City Name: axim.
# Retrieving Row 980, City Name: texarkana.
# Retrieving Row 981, City Name: lolua.
# Oops, Record 981 city: lolua not found!
# Retrieving Row 983, City Name: shangrao.
# Retrieving Row 984, City Name: salina.
# Retrieving Row 987, City Name: tessalit.
# Retrieving Row 994, City Name: kavieng.
# Retrieving Row 1014, City Name: inta.
# Retrieving Row 1016, City Name: nanchang.
# Retrieving Row 1020, City Name: besancon.
# Retrieving Row 1021, City Name: galle.
# Retrieving Row 1025, City Name: collie.
# Retrieving Row 1027, City Name: ormara.
# Retrieving Row 1028, City Name: treinta y tres.
# Retrieving Row 1029, City Name: nadym.
# Retrieving Row 1031, City Name: mackay.
# Retrieving Row 1033, City Name: porto seguro.
# Retrieving Row 1036, City Name: agua prieta.
# Retrieving Row 1037, City Name: labuhan.
# Retrieving Row 1038, City Name: zhigansk.
# Retrieving Row 1041, City Name: antofagasta.
# Retrieving Row 1045, City Name: mahajanga.
# Retrieving Row 1051, City Name: arman.
# Retrieving Row 1055, City Name: kruisfontein.
# Retrieving Row 1059, City Name: tonantins.
# Retrieving Row 1064, City Name: nizhnevartovsk.
# Retrieving Row 1065, City Name: rawannawi.
# Oops, Record 1065 city: rawannawi not found!
# Retrieving Row 1067, City Name: torzhok.
# Retrieving Row 1069, City Name: virden.
# Retrieving Row 1070, City Name: sapucaia.
# Retrieving Row 1076, City Name: kaoma.
# Retrieving Row 1078, City Name: dwarka.
# Retrieving Row 1079, City Name: yumen.
# Retrieving Row 1081, City Name: batagay.
# Retrieving Row 1082, City Name: marcona.
# Oops, Record 1082 city: marcona not found!
# Retrieving Row 1089, City Name: oktyabrskiy.
# Retrieving Row 1093, City Name: salinopolis.
# Retrieving Row 1094, City Name: henties bay.
# Retrieving Row 1096, City Name: san vicente.
# Retrieving Row 1111, City Name: kautokeino.
# Retrieving Row 1114, City Name: alofi.
# Retrieving Row 1119, City Name: kieta.
# Retrieving Row 1121, City Name: walvis bay.
# Retrieving Row 1122, City Name: churapcha.
# Retrieving Row 1123, City Name: primore.
# Oops, Record 1123 city: primore not found!
# Retrieving Row 1128, City Name: strezhevoy.
# Retrieving Row 1130, City Name: hailey.
# Retrieving Row 1132, City Name: singaraja.
# Retrieving Row 1136, City Name: hambantota.
# Retrieving Row 1137, City Name: ust-tsilma.
# Retrieving Row 1138, City Name: datong.
# Retrieving Row 1144, City Name: taunton.
# Retrieving Row 1152, City Name: villa sandino.
# Retrieving Row 1153, City Name: cangzhou.
# Retrieving Row 1154, City Name: aras.
# Oops, Record 1154 city: aras not found!
# Retrieving Row 1158, City Name: moussoro.
# Retrieving Row 1161, City Name: tornio.
# Retrieving Row 1166, City Name: dunedin.
# Retrieving Row 1173, City Name: halmeu.
# Retrieving Row 1177, City Name: humaita.
# Retrieving Row 1183, City Name: hobyo.
# Retrieving Row 1191, City Name: the valley.
# Retrieving Row 1193, City Name: touzim.
# Retrieving Row 1195, City Name: hvammstangi.
# Oops, Record 1195 city: hvammstangi not found!
# Retrieving Row 1196, City Name: pata.
# Oops, Record 1196 city: pata not found!
# Retrieving Row 1198, City Name: praia da vitoria.
# Retrieving Row 1202, City Name: jamsa.
# Retrieving Row 1204, City Name: tolosa.
# Retrieving Row 1211, City Name: lyantonde.
# Retrieving Row 1212, City Name: leh.
# Retrieving Row 1227, City Name: camacha.
# Retrieving Row 1228, City Name: pratapgarh.
# Retrieving Row 1229, City Name: teruel.
# Retrieving Row 1232, City Name: luba.
# Retrieving Row 1233, City Name: santa maria.
# Retrieving Row 1234, City Name: mys shmidta.
# Oops, Record 1234 city: mys shmidta not found!
# Retrieving Row 1236, City Name: emerald.
# Retrieving Row 1244, City Name: port augusta.
# Retrieving Row 1245, City Name: coahuayana.
# Retrieving Row 1250, City Name: baghdad.
# Retrieving Row 1252, City Name: mbengwi.
# Retrieving Row 1253, City Name: novoseleznevo.
# Retrieving Row 1255, City Name: namatanai.
# Retrieving Row 1256, City Name: narnaul.
# Retrieving Row 1258, City Name: nenjiang.
# Retrieving Row 1262, City Name: klaksvik.
# Retrieving Row 1266, City Name: boromo.
# Retrieving Row 1271, City Name: anchorage.
# Retrieving Row 1272, City Name: barda.
# Retrieving Row 1273, City Name: ust-kuyga.
# Retrieving Row 1278, City Name: tezu.
# Retrieving Row 1281, City Name: joson.
# Retrieving Row 1286, City Name: yuzhno-kurilsk.
# Retrieving Row 1289, City Name: tshikapa.
# Retrieving Row 1293, City Name: kloulklubed.
# Retrieving Row 1294, City Name: marathopolis.
# Oops, Record 1294 city: marathopolis not found!
# Retrieving Row 1295, City Name: dalbandin.
# Retrieving Row 1297, City Name: pontes e lacerda.
# Retrieving Row 1301, City Name: luderitz.
# Retrieving Row 1302, City Name: sao joao da barra.
# Retrieving Row 1306, City Name: chenzhou.
# Retrieving Row 1307, City Name: sadon.
# Retrieving Row 1311, City Name: alekseyevsk.
# Retrieving Row 1313, City Name: longhua.
# Retrieving Row 1314, City Name: stornoway.
# Retrieving Row 1318, City Name: klyuchi.
# Retrieving Row 1321, City Name: eureka.
# Retrieving Row 1323, City Name: parrita.
# Retrieving Row 1326, City Name: sur.
# Retrieving Row 1327, City Name: machali.
# Retrieving Row 1331, City Name: fukue.
# Retrieving Row 1333, City Name: poim.
# Retrieving Row 1340, City Name: fortuna.
# Retrieving Row 1342, City Name: tommot.
# Retrieving Row 1343, City Name: aleksandrovsk-sakhalinskiy.
# Retrieving Row 1346, City Name: vammala.
# Retrieving Row 1350, City Name: yelovo.
# Retrieving Row 1355, City Name: poum.
# Retrieving Row 1356, City Name: altamira.
# Retrieving Row 1357, City Name: monkey bay.
# Retrieving Row 1364, City Name: xiaoweizhai.
# Retrieving Row 1376, City Name: zhangjiakou.
# Retrieving Row 1378, City Name: whitecourt.
# Retrieving Row 1382, City Name: trabzon.
# Retrieving Row 1383, City Name: middle island.
# Oops, Record 1383 city: middle island not found!
# Retrieving Row 1384, City Name: umm jarr.
# Oops, Record 1384 city: umm jarr not found!
# Retrieving Row 1391, City Name: matay.
# Retrieving Row 1399, City Name: huron.
# Retrieving Row 1406, City Name: mandera.
# Retrieving Row 1408, City Name: lac du bonnet.
# Retrieving Row 1410, City Name: abu kamal.
# Retrieving Row 1411, City Name: ofunato.
# Retrieving Row 1413, City Name: luanda.
# Retrieving Row 1415, City Name: nagato.
# Retrieving Row 1416, City Name: wencheng.
# Retrieving Row 1417, City Name: omboue.
# Retrieving Row 1419, City Name: portland.
# Retrieving Row 1424, City Name: waddan.
# Retrieving Row 1425, City Name: saint-ambroise.
# Retrieving Row 1427, City Name: luena.
# Retrieving Row 1431, City Name: nishihara.
# Retrieving Row 1432, City Name: khash.
# Retrieving Row 1434, City Name: borogontsy.
# Retrieving Row 1438, City Name: seredka.
# Retrieving Row 1442, City Name: san jose.
# Retrieving Row 1449, City Name: emborion.
# Retrieving Row 1450, City Name: vinhedo.
# Retrieving Row 1458, City Name: mwinilunga.
# Retrieving Row 1464, City Name: saint-augustin.
# Retrieving Row 1466, City Name: mandan.
# Retrieving Row 1470, City Name: areosa.
# Retrieving Row 1472, City Name: richards bay.
# Retrieving Row 1475, City Name: skalistyy.
# Oops, Record 1475 city: skalistyy not found!
# Retrieving Row 1480, City Name: khorramshahr.
# Retrieving Row 1485, City Name: mattru.
# Retrieving Row 1487, City Name: clifton.
# Retrieving Row 1488, City Name: nova olimpia.
# Retrieving Row 1490, City Name: puerto madero.
# Retrieving Row 1491, City Name: tiznit.
# Retrieving Row 1500, City Name: cabanbanan.
# Retrieving Row 1501, City Name: nabire.
# Retrieving Row 1502, City Name: chapleau.
# Retrieving Row 1503, City Name: souillac.
# Retrieving Row 1508, City Name: broken hill.
# Retrieving Row 1514, City Name: onalaska.
# Retrieving Row 1515, City Name: najran.
# Retrieving Row 1519, City Name: chokwe.
# Retrieving Row 1521, City Name: victoria.
# Retrieving Row 1526, City Name: punta alta.
# Retrieving Row 1527, City Name: beringovskiy.
# Retrieving Row 1528, City Name: mayumba.
# Retrieving Row 1533, City Name: muroto.
# Retrieving Row 1536, City Name: dawson creek.
# Retrieving Row 1539, City Name: chongwe.
# Retrieving Row 1541, City Name: sinaloa.
# Retrieving Row 1545, City Name: rudnogorsk.
# Retrieving Row 1557, City Name: acuna.
# Oops, Record 1557 city: acuna not found!
# Retrieving Row 1561, City Name: sarandi.
# Retrieving Row 1562, City Name: labutta.
# Oops, Record 1562 city: labutta not found!
# Retrieving Row 1570, City Name: christchurch.
# Retrieving Row 1574, City Name: havre-saint-pierre.
# Retrieving Row 1577, City Name: svetlyy.
# Retrieving Row 1588, City Name: gori.
# Retrieving Row 1589, City Name: udachnyy.
# Retrieving Row 1590, City Name: kasane.
# Retrieving Row 1592, City Name: zhucheng.
# Retrieving Row 1594, City Name: san ignacio.
# Oops, Record 1594 city: san ignacio not found!
# Retrieving Row 1595, City Name: porto santo.
# Retrieving Row 1596, City Name: alcudia.
# Retrieving Row 1598, City Name: antsohihy.
# Retrieving Row 1599, City Name: xinzhi.
# Retrieving Row 1600, City Name: poya.
# Retrieving Row 1601, City Name: bonavista.
# Retrieving Row 1603, City Name: juifang.
# Oops, Record 1603 city: juifang not found!
# Retrieving Row 1604, City Name: vila do maio.
# Retrieving Row 1606, City Name: flagstaff.
# Retrieving Row 1607, City Name: bosaso.
# Retrieving Row 1608, City Name: jinka.
# Retrieving Row 1611, City Name: erzin.
# Retrieving Row 1612, City Name: jibuti.
# Retrieving Row 1614, City Name: lavrentiya.
# Retrieving Row 1616, City Name: alice springs.
# Retrieving Row 1627, City Name: kazuno.
# Retrieving Row 1632, City Name: alice town.
# Retrieving Row 1635, City Name: kiboga.
# Retrieving Row 1637, City Name: kota tinggi.
# Retrieving Row 1638, City Name: tivaouane.
# Retrieving Row 1648, City Name: mount isa.
# Retrieving Row 1649, City Name: halifax.
# Retrieving Row 1651, City Name: cururupu.
# Retrieving Row 1665, City Name: sabha.
# Retrieving Row 1667, City Name: kutum.
# Retrieving Row 1676, City Name: baie-comeau.
# Retrieving Row 1683, City Name: nanyuki.
# Retrieving Row 1684, City Name: alegrete.
# Retrieving Row 1686, City Name: varzea da palma.
# Retrieving Row 1688, City Name: porto velho.
# Retrieving Row 1694, City Name: simav.
# Retrieving Row 1698, City Name: xuanzhou.
# Retrieving Row 1700, City Name: ouesso.
# Retrieving Row 1701, City Name: deputatskiy.
# Retrieving Row 1710, City Name: opobo.
# Oops, Record 1710 city: opobo not found!
# Retrieving Row 1711, City Name: meulaboh.
# Retrieving Row 1713, City Name: bac can.
# Oops, Record 1713 city: bac can not found!
# Retrieving Row 1721, City Name: lokosovo.
# Retrieving Row 1723, City Name: bac lieu.
# Retrieving Row 1724, City Name: taybad.
# Retrieving Row 1726, City Name: sijunjung.
# Retrieving Row 1727, City Name: vetluga.
# Retrieving Row 1731, City Name: satitoa.
# Oops, Record 1731 city: satitoa not found!
# Retrieving Row 1734, City Name: tabuk.
# Retrieving Row 1745, City Name: dom pedrito.
# Retrieving Row 1746, City Name: san andres.
# Retrieving Row 1749, City Name: barcelos.
# Retrieving Row 1754, City Name: ust-kamchatsk.
# Oops, Record 1754 city: ust-kamchatsk not found!
# Retrieving Row 1757, City Name: tottori.
# Retrieving Row 1758, City Name: plettenberg bay.
# Retrieving Row 1762, City Name: half moon bay.
# Retrieving Row 1769, City Name: yuancheng.
# Retrieving Row 1771, City Name: inderborskiy.
# Oops, Record 1771 city: inderborskiy not found!
# Retrieving Row 1774, City Name: great yarmouth.
# Retrieving Row 1779, City Name: mikhaylovskoye.
# Retrieving Row 1783, City Name: neuruppin.
# Retrieving Row 1787, City Name: svetlaya.
# Retrieving Row 1791, City Name: prainha.
# Retrieving Row 1796, City Name: redwater.
# Retrieving Row 1798, City Name: raton.
# Retrieving Row 1800, City Name: gouyave.
# Retrieving Row 1802, City Name: viedma.
# Retrieving Row 1810, City Name: hay river.
# Retrieving Row 1812, City Name: les cayes.
# Retrieving Row 1814, City Name: hikari.
# Retrieving Row 1817, City Name: ntungamo.
# Retrieving Row 1819, City Name: kaduqli.
# Retrieving Row 1820, City Name: san policarpo.
# Retrieving Row 1823, City Name: swan hill.
# Retrieving Row 1826, City Name: turmalina.
# Retrieving Row 1832, City Name: haldia.
# Retrieving Row 1835, City Name: kamalpur.
# Retrieving Row 1836, City Name: vrangel.
# Retrieving Row 1839, City Name: iracoubo.
# Retrieving Row 1843, City Name: halalo.
# Oops, Record 1843 city: halalo not found!
# Retrieving Row 1846, City Name: boa vista.
# Retrieving Row 1851, City Name: umzimvubu.
# Oops, Record 1851 city: umzimvubu not found!
# Retrieving Row 1852, City Name: praia.
# Retrieving Row 1854, City Name: qaqortoq.
# Retrieving Row 1857, City Name: san carlos de bariloche.
# Retrieving Row 1860, City Name: rungata.
# Oops, Record 1860 city: rungata not found!
# Retrieving Row 1862, City Name: ziyang.
# Retrieving Row 1868, City Name: yatou.
# Retrieving Row 1881, City Name: camapua.
# Retrieving Row 1884, City Name: uvat.
# Retrieving Row 1889, City Name: santa rosa.
# Retrieving Row 1892, City Name: olinda.
# Retrieving Row 1895, City Name: waipawa.
# Retrieving Row 1899, City Name: beyneu.
# Retrieving Row 1903, City Name: tokur.
# Retrieving Row 1904, City Name: el wasta.
# Oops, Record 1904 city: el wasta not found!
# Retrieving Row 1908, City Name: georgetown.
# Retrieving Row 1913, City Name: marsa matruh.
# Retrieving Row 1915, City Name: nevel.
# Retrieving Row 1918, City Name: lemesos.
# Oops, Record 1918 city: lemesos not found!
# Retrieving Row 1921, City Name: quatre cocos.
# Retrieving Row 1923, City Name: mammaste.
# Retrieving Row 1924, City Name: falealupo.
# Oops, Record 1924 city: falealupo not found!
# Retrieving Row 1927, City Name: bacuit.
# Oops, Record 1927 city: bacuit not found!
# Retrieving Row 1928, City Name: kaniama.
# Retrieving Row 1929, City Name: dumai.
# Retrieving Row 1936, City Name: uige.
# Retrieving Row 1937, City Name: sumbawa.
# Oops, Record 1937 city: sumbawa not found!
# Retrieving Row 1941, City Name: san ramon.
# Retrieving Row 1944, City Name: dolores.
# Retrieving Row 1945, City Name: manta.
# Retrieving Row 1950, City Name: egvekinot.
# Retrieving Row 1952, City Name: bocaranga.
# Oops, Record 1952 city: bocaranga not found!
# Retrieving Row 1954, City Name: tumwater.
# Retrieving Row 1958, City Name: marrakesh.
# Retrieving Row 1969, City Name: bilma.
# Retrieving Row 1974, City Name: kushima.
# Retrieving Row 1978, City Name: salalah.
# Retrieving Row 1985, City Name: kundiawa.
# Retrieving Row 1993, City Name: qui nhon.
# Retrieving Row 1994, City Name: geelong.
# Retrieving Row 1996, City Name: pimentel.
# Retrieving Row 1997, City Name: londoko.
# -----------------------------
# Data Retrieval Complete!

# %%
#change all data recieved from openweathermap api to numerical data
city_df['Latitude'] = pd.to_numeric(city_df['Latitude'])
city_df['Longitude'] = pd.to_numeric(city_df['Longitude'])
city_df['Max Temperature (F)'] = pd.to_numeric(city_df['Max Temperature (F)'])
city_df['Humidity (%)'] = pd.to_numeric(city_df['Humidity (%)'])
city_df['Cloudiness (%)'] = pd.to_numeric(city_df['Cloudiness (%)'])
city_df['Wind Speed (mph)'] = pd.to_numeric(city_df['Wind Speed (mph)'])

# %%
#remove rows and columns with None values
new_city_df=city_df[city_df['Date'] != ""]
new_city_df.reset_index(inplace=True)
del new_city_df['index']
print("We have {} cities containing weather information.".format(len(new_city_df)))
# Out:
# We have 677 cities containing weather information.

# %% [markdown]
# ### Export DataFrame to CSV File

# %%
new_city_df.to_csv("weatherpy_data.csv", encoding="utf-8", index=False)

# %% [markdown]
# #  Build scatter plots to showcase the following relationships:
# * Temperature (F) vs. Latitude
# * Humidity (%) vs. Latitude
# * Cloudiness (%) vs. Latitude
# * Wind Speed (mph) vs. Latitude

# %% [markdown]
# ### Temperature (F) vs. Latitude

# %%
#Temperature (F) vs. Latitude
new_city_df.plot(kind="scatter", x="Latitude", y="Max Temperature (F)", grid=True, figsize=(8,8),
              title="Latitude vs Temperature") 
plt.savefig("Latitude vs Temperature.jpeg")
plt.show()

# %% [markdown]
# #### The cities near the equator have higher temperatures and the cities which are far away from the equator have lower temperature.

# %% [markdown]
# ### Humidity (%) vs. Latitude

# %%
#Humidity (%) vs. Latitude
new_city_df.plot(kind="scatter", x="Latitude", y="Humidity (%)", grid=True, figsize=(8,8),
              title="Latitude vs Humidity") 
plt.savefig("Latitude vs Humidity.jpeg")
plt.show()

# %% [markdown]
# #### It seems that there is no real pattern that can describe the relationship between latitude and humidity

# %% [markdown]
# ### Cloudiness (%) vs. Latitude

# %%
#Cloudiness (%) vs. Latitude
new_city_df.plot(kind="scatter", x="Latitude", y="Cloudiness (%)", grid=True, figsize=(8,8),
              title="Latitude vs Cloudiness") 
plt.savefig("Latitude vs Cloudiness.jpeg")
plt.show()

# %% [markdown]
# #### It seems that there is no real pattern that can describe the relationship between latitude and Cloudiness

# %% [markdown]
# ### Wind Speed (mph) vs. Latitude

# %%
#Wind Speed (mph) vs. Latitude
new_city_df.plot(kind="scatter", x="Latitude", y="Wind Speed (mph)", grid=True, figsize=(8,8),
              title="Latitude vs Wind Speed") 
plt.savefig("Latitude vs Wind Speed.jpeg")
plt.show()

# %% [markdown]
# #### It seems that there is no real pattern that can describe the relationship between latitude and windspeed

# %% [markdown]
# ## Perform linear regression on each relationship
#
# * Northern Hemisphere - Temperature (F) vs. Latitude
# * Southern Hemisphere - Temperature (F) vs. Latitude
# * Northern Hemisphere - Humidity (%) vs. Latitude
# * Southern Hemisphere - Humidity (%) vs. Latitude
# * Northern Hemisphere - Cloudiness (%) vs. Latitude
# * Southern Hemisphere - Cloudiness (%) vs. Latitude
# * Northern Hemisphere - Wind Speed (mph) vs. Latitude
# * Southern Hemisphere - Wind Speed (mph) vs. Latitude

# %%
Northern_Hemisphere=new_city_df[new_city_df['Latitude']>0]
Southern_Hemisphere=new_city_df[new_city_df['Latitude']<0]

# %%
#Northern Hemisphere - Temperature (F) vs. Latitude
x_values = Northern_Hemisphere['Latitude']
y_values = Northern_Hemisphere['Max Temperature (F)']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title("Latitude vs Temperature (F) in Northern Hemisphere")
print(f"Regression line equation is: {line_eq}")
print(f"The r-squared is: {round(rvalue, 2)}")
print("The regression displays a negative correlation.")
print("In the Northern hemisphere, as the cities get closer to the equator, the temperature decreases.")
plt.savefig("Northern Hemisphere - Latitude vs Temperature (F).jpeg")
plt.show()
# Out:
# Regression line equation is: y = -1.23x + 92.82
# The r-squared is: -0.9
# The regression displays a negative correlation.
# In the Northern hemisphere, as the cities get closer to the equator, the temperature decreases.

# %%
#Southern Hemisphere - Temperature (F) vs. Latitude
x_values = Southern_Hemisphere['Latitude']
y_values = Southern_Hemisphere['Max Temperature (F)']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,60),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title("Latitude vs Temperature (F) in Southern Hemisphere")
print(f"Regression line equation is: {line_eq}")
print(f"The r-squared is: {round(rvalue, 2)}")
print("The regression displays a positive correlation.")
print("In the Southern hemisphere, as the cities get closer to the equator, the temperature increases.")
plt.savefig("Southern Hemisphere - Latitude vs Temperature (F).jpeg")
plt.show()
# Out:
# Regression line equation is: y = 0.39x + 81.97
# The r-squared is: 0.51
# The regression displays a positive correlation.
# In the Southern hemisphere, as the cities get closer to the equator, the temperature increases.

# %%
#Northern Hemisphere - Humidity (%) vs. Latitude
x_values = Northern_Hemisphere['Latitude']
y_values = Northern_Hemisphere['Humidity (%)']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,40),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title("Latitude vs Humidity (%) in Northern Hemisphere")
print(f"The r-squared is: {round(rvalue, 2)}")
print("The regression is generally considered a None or Very weak relationship between latitude and humidity") 
plt.savefig("Northern Hemisphere - Latitude vs Humidity (%).jpeg")
plt.show()
# Out:
# The r-squared is: 0.28
# The regression is generally considered a None or Very weak relationship between latitude and humidity

# %%
#Southern Hemisphere - Humidity (%) vs. Latitude
x_values = Southern_Hemisphere['Latitude']
y_values = Southern_Hemisphere['Humidity (%)']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,60),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title("Latitude vs Humidity (%) in Southern Hemisphere")
print(f"The r-squared is: {round(rvalue, 2)}")
print("The regression is generally considered a None or Very weak relationship between latitude and humidity") 
plt.savefig("Southern Hemisphere - Latitude vs Humidity (%).jpeg")
plt.show()
# Out:
# The r-squared is: 0.27
# The regression is generally considered a None or Very weak relationship between latitude and humidity

# %%
#Northern Hemisphere - Cloudiness (%) vs. Latitude
x_values = Northern_Hemisphere['Latitude']
y_values = Northern_Hemisphere['Cloudiness (%)']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,25),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title("Latitude vs Cloudiness (%) in Northern Hemisphere")
print(f"The r-squared is: {round(rvalue, 2)}")
print("The regression is generally considered a None or Very weak relationship between latitude and cloudiness") 
plt.savefig("Northern Hemisphere - Latitude vs Cloudiness (%).jpeg")
plt.show()
# Out:
# The r-squared is: 0.28
# The regression is generally considered a None or Very weak relationship between latitude and cloudiness

# %%
#Southern Hemisphere - Cloudiness (%) vs. Latitude
x_values = Southern_Hemisphere['Latitude']
y_values = Southern_Hemisphere['Cloudiness (%)']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,25),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title("Latitude vs Cloudiness (%) in Southern Hemisphere")
print(f"The r-squared is: {round(rvalue, 2)}")
print("The regression is generally considered a None or Very weak relationship between latitude and Cloudiness.") 
plt.savefig("Southern Hemisphere - Latitude vs Cloudiness (%).jpeg")
plt.show()
# Out:
# The r-squared is: 0.25
# The regression is generally considered a None or Very weak relationship between latitude and Cloudiness.

# %%
#Northern Hemisphere - Wind Speed (mph) vs. Latitude
x_values = Northern_Hemisphere['Latitude']
y_values = Northern_Hemisphere['Wind Speed (mph)']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,25),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title("Latitude vs Wind Speed (mph) in Northern Hemisphere")
print(f"The r-squared is: {round(rvalue, 2)}")
print("The regression is generally considered a None or Very weak relationship between latitude and wind speed") 
plt.savefig("Northern Hemisphere - Latitude vs Wind Speed (mph).jpeg")
plt.show()
# Out:
# The r-squared is: 0.27
# The regression is generally considered a None or Very weak relationship between latitude and wind speed

# %%
#Southern Hemisphere - Wind Speed (mph) vs. Latitude
x_values = Southern_Hemisphere['Latitude']
y_values = Southern_Hemisphere['Wind Speed (mph)']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,25),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title("Latitude vs Wind Speed (mph) in Southern Hemisphere")
print(f"The r-squared is: {round(rvalue, 2)}")
print("The regression is generally considered a None or Very weak relationship between latitude and wind speed") 
plt.savefig("Southern Hemisphere - Latitude vs Wind Speed (mph).jpeg")
plt.show()
# Out:
# The r-squared is: -0.24
# The regression is generally considered a None or Very weak relationship between latitude and wind speed

# %% [markdown]
# # Observations

# %% [markdown]
# * Temperature has a strong correlation with the latitude. Temperature decreases as latitude moves away from equator.
# * There is no relationship between latitude and humidity.
# * Although not obvious, there is a weak linear relationship between cloundiness and latitude in Northern Hemisphere: As latitute increases, Wind Speed increases.
