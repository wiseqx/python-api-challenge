# %% [markdown]
# # Import libraries

# %%
# Dependencies
import matplotlib.pyplot as plt
import requests
import pandas as pd
from config import api_key
import json
import numpy as np
from citipy import citipy
from scipy.stats import linregress
import datetime

# %% [markdown]
# # Generate random list for latitudes and longitudes

# %%
#Generate random list for latitudes and longitudes
np.random.seed(2)
latitude=[lat for lat in np.random.randint(-90,90,2000)]
longitude=[lon for lon in np.random.randint(-180,180,2000)]

# %%
latitude_and_Longitude = tuple(zip(latitude,longitude))

# %% [markdown]
# # Find Nearest City

# %%
#use citipy library to find the nearest city for all latitudes and longitudes
cities = []
countries = []

for lat, lon in latitude_and_Longitude:
    city = citipy.nearest_city(lat,lon)
    city_name = city.city_name
    cities.append(city_name)
    countries.append(city.country_code)

# %% [markdown]
# ## Generate Dataframe for all information

# %%
city_df = pd.DataFrame({'City': cities, 'Country': countries})
city_df = city_df.drop_duplicates(subset=['City'],keep='first')
city_df['Date']=""
city_df['Latitude'] = ''
city_df['Longitude'] = ''
city_df['Max Temperature (F)'] = ''
city_df['Humidity (%)'] = ''
city_df['Cloudiness (%)'] = ''
city_df['Wind Speed (mph)'] = ''
city_df.head()
# Out:
#            City Country Date Latitude Longitude Max Temperature (F)  \
# 0        hobart      au
# 1   provideniya      ru
# 2     jamestown      sh
# 3  plaster rock      ca
# 4        iwanai      jp
#
#   Humidity (%) Cloudiness (%) Wind Speed (mph)
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Perform Openweathermap API calls

# %%
url="http://api.openweathermap.org/data/2.5/weather?q="
units="imperial"

# %%
from pprint import pprint
for index, row in city_df.iterrows():
    city = row['City']
    country_code = row['Country']
    query_url = url + city + ',' + country_code + '&units=' + units + '&APPID=' + api_key
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()

    pprint(weather_json)
    try:
        print(f"Processing Record {index}, City Name: {city}.")
        city_df.loc[index,'Date']=datetime.datetime.fromtimestamp(weather_json['dt'])
        city_df.loc[index,'Latitude']=weather_json['coord']['lat']
        city_df.loc[index,'Longitude']=weather_json['coord']['lon']
        city_df.loc[index,'Max Temperature (F)']=weather_json['main']['temp_max']
        city_df.loc[index, 'Humidity (%)']=weather_json['main']['humidity']
        city_df.loc[index, 'Cloudiness (%)']=weather_json['clouds']['all']
        city_df.loc[index, 'Wind Speed (mph)']=weather_json['wind']['speed']
        
    
    except:
#         city_df.loc[index,'Date']=np.nan
#         city_df.loc[index,'Latitude']=np.nan
#         city_df.loc[index,'Longitude']=np.nan
#         city_df.loc[index,'Max Temperature (F)']=np.nan
#         city_df.loc[index, 'Humidity (%)']=np.nan
#         city_df.loc[index, 'Cloudiness (%)']=np.nan
#         city_df.loc[index, 'Wind Speed (mph)']=np.nan
        print(f"Oops, Record {index} city: {city} not found! ")

print("-----------------------------")        
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 0, City Name: hobart.
# Oops, Record 0 city: hobart not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 1, City Name: provideniya.
# Oops, Record 1 city: provideniya not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 2, City Name: jamestown.
# Oops, Record 2 city: jamestown not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 3, City Name: plaster rock.
# Oops, Record 3 city: plaster rock not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 4, City Name: iwanai.
# Oops, Record 4 city: iwanai not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 5, City Name: luau.
# Oops, Record 5 city: luau not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 6, City Name: navahrudak.
# Oops, Record 6 city: navahrudak not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 7, City Name: sinnai.
# Oops, Record 7 city: sinnai not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 8, City Name: puerto ayora.
# Oops, Record 8 city: puerto ayora not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 9, City Name: north bend.
# Oops, Record 9 city: north bend not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 10, City Name: mataura.
# Oops, Record 10 city: mataura not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 11, City Name: tuktoyaktuk.
# Oops, Record 11 city: tuktoyaktuk not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 12, City Name: busselton.
# Oops, Record 12 city: busselton not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 13, City Name: coahuayana.
# Oops, Record 13 city: coahuayana not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 14, City Name: meadow lake.
# Oops, Record 14 city: meadow lake not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 15, City Name: moron.
# Oops, Record 15 city: moron not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 16, City Name: thompson.
# Oops, Record 16 city: thompson not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 17, City Name: brae.
# Oops, Record 17 city: brae not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 18, City Name: katangli.
# Oops, Record 18 city: katangli not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 19, City Name: ancud.
# Oops, Record 19 city: ancud not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 20, City Name: marcona.
# Oops, Record 20 city: marcona not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 21, City Name: wattegama.
# Oops, Record 21 city: wattegama not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 22, City Name: gamba.
# Oops, Record 22 city: gamba not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 23, City Name: bethel.
# Oops, Record 23 city: bethel not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 24, City Name: dingle.
# Oops, Record 24 city: dingle not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 26, City Name: broken hill.
# Oops, Record 26 city: broken hill not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 27, City Name: bambous virieux.
# Oops, Record 27 city: bambous virieux not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 28, City Name: punta arenas.
# Oops, Record 28 city: punta arenas not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 29, City Name: gualeguay.
# Oops, Record 29 city: gualeguay not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 30, City Name: ushuaia.
# Oops, Record 30 city: ushuaia not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 31, City Name: beckley.
# Oops, Record 31 city: beckley not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 32, City Name: butia.
# Oops, Record 32 city: butia not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 34, City Name: kluczbork.
# Oops, Record 34 city: kluczbork not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 35, City Name: kapaa.
# Oops, Record 35 city: kapaa not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 36, City Name: illoqqortoormiut.
# Oops, Record 36 city: illoqqortoormiut not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 37, City Name: lasa.
# Oops, Record 37 city: lasa not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 38, City Name: cape town.
# Oops, Record 38 city: cape town not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 39, City Name: camapua.
# Oops, Record 39 city: camapua not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 40, City Name: grand island.
# Oops, Record 40 city: grand island not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 43, City Name: mahebourg.
# Oops, Record 43 city: mahebourg not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 44, City Name: port alfred.
# Oops, Record 44 city: port alfred not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 45, City Name: chuy.
# Oops, Record 45 city: chuy not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 47, City Name: mufumbwe.
# Oops, Record 47 city: mufumbwe not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 49, City Name: arraial do cabo.
# Oops, Record 49 city: arraial do cabo not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 50, City Name: luanda.
# Oops, Record 50 city: luanda not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 51, City Name: saint-francois.
# Oops, Record 51 city: saint-francois not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 52, City Name: jalu.
# Oops, Record 52 city: jalu not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 54, City Name: albany.
# Oops, Record 54 city: albany not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 55, City Name: yulara.
# Oops, Record 55 city: yulara not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 56, City Name: hermanus.
# Oops, Record 56 city: hermanus not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 57, City Name: mecca.
# Oops, Record 57 city: mecca not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 58, City Name: urumqi.
# Oops, Record 58 city: urumqi not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 61, City Name: puerto madero.
# Oops, Record 61 city: puerto madero not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 64, City Name: barbate.
# Oops, Record 64 city: barbate not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 65, City Name: new norfolk.
# Oops, Record 65 city: new norfolk not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 66, City Name: heze.
# Oops, Record 66 city: heze not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 67, City Name: lorengau.
# Oops, Record 67 city: lorengau not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 68, City Name: kenai.
# Oops, Record 68 city: kenai not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 69, City Name: khatanga.
# Oops, Record 69 city: khatanga not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 70, City Name: sao joao da barra.
# Oops, Record 70 city: sao joao da barra not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 71, City Name: canutama.
# Oops, Record 71 city: canutama not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 72, City Name: pevek.
# Oops, Record 72 city: pevek not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 73, City Name: carballo.
# Oops, Record 73 city: carballo not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 75, City Name: clyde river.
# Oops, Record 75 city: clyde river not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 77, City Name: taolanaro.
# Oops, Record 77 city: taolanaro not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 78, City Name: petropavlovsk-kamchatskiy.
# Oops, Record 78 city: petropavlovsk-kamchatskiy not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 79, City Name: sungaipenuh.
# Oops, Record 79 city: sungaipenuh not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 81, City Name: bumba.
# Oops, Record 81 city: bumba not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 82, City Name: arinos.
# Oops, Record 82 city: arinos not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 84, City Name: college.
# Oops, Record 84 city: college not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 85, City Name: la ronge.
# Oops, Record 85 city: la ronge not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 86, City Name: ramotswa.
# Oops, Record 86 city: ramotswa not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 87, City Name: butaritari.
# Oops, Record 87 city: butaritari not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 88, City Name: sola.
# Oops, Record 88 city: sola not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 90, City Name: yumen.
# Oops, Record 90 city: yumen not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 91, City Name: port elizabeth.
# Oops, Record 91 city: port elizabeth not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 92, City Name: umzimvubu.
# Oops, Record 92 city: umzimvubu not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 94, City Name: faanui.
# Oops, Record 94 city: faanui not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 95, City Name: sosva.
# Oops, Record 95 city: sosva not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 97, City Name: georgetown.
# Oops, Record 97 city: georgetown not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 98, City Name: rikitea.
# Oops, Record 98 city: rikitea not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 100, City Name: coihaique.
# Oops, Record 100 city: coihaique not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 104, City Name: sao filipe.
# Oops, Record 104 city: sao filipe not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 106, City Name: bredasdorp.
# Oops, Record 106 city: bredasdorp not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 107, City Name: lebu.
# Oops, Record 107 city: lebu not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 108, City Name: bandarbeyla.
# Oops, Record 108 city: bandarbeyla not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 110, City Name: east london.
# Oops, Record 110 city: east london not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 111, City Name: saint-philippe.
# Oops, Record 111 city: saint-philippe not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 112, City Name: nikolskoye.
# Oops, Record 112 city: nikolskoye not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 114, City Name: ormstown.
# Oops, Record 114 city: ormstown not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 115, City Name: agadir.
# Oops, Record 115 city: agadir not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 116, City Name: voyvozh.
# Oops, Record 116 city: voyvozh not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 117, City Name: ballina.
# Oops, Record 117 city: ballina not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 118, City Name: klaksvik.
# Oops, Record 118 city: klaksvik not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 119, City Name: drabiv.
# Oops, Record 119 city: drabiv not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 122, City Name: polunochnoye.
# Oops, Record 122 city: polunochnoye not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 124, City Name: marzuq.
# Oops, Record 124 city: marzuq not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 126, City Name: ribeira grande.
# Oops, Record 126 city: ribeira grande not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 127, City Name: hilo.
# Oops, Record 127 city: hilo not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 130, City Name: ouidah.
# Oops, Record 130 city: ouidah not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 131, City Name: soyo.
# Oops, Record 131 city: soyo not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 132, City Name: toamasina.
# Oops, Record 132 city: toamasina not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 136, City Name: sentyabrskiy.
# Oops, Record 136 city: sentyabrskiy not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 137, City Name: attawapiskat.
# Oops, Record 137 city: attawapiskat not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 141, City Name: qaanaaq.
# Oops, Record 141 city: qaanaaq not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 143, City Name: dergachi.
# Oops, Record 143 city: dergachi not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 144, City Name: san quintin.
# Oops, Record 144 city: san quintin not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 145, City Name: atuona.
# Oops, Record 145 city: atuona not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 146, City Name: lata.
# Oops, Record 146 city: lata not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 148, City Name: cabo san lucas.
# Oops, Record 148 city: cabo san lucas not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 149, City Name: coquimbo.
# Oops, Record 149 city: coquimbo not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 151, City Name: ust-maya.
# Oops, Record 151 city: ust-maya not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 152, City Name: saint-georges.
# Oops, Record 152 city: saint-georges not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 154, City Name: grindavik.
# Oops, Record 154 city: grindavik not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 155, City Name: ekibastuz.
# Oops, Record 155 city: ekibastuz not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 156, City Name: codrington.
# Oops, Record 156 city: codrington not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 157, City Name: castro.
# Oops, Record 157 city: castro not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 158, City Name: erenhot.
# Oops, Record 158 city: erenhot not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 159, City Name: nanortalik.
# Oops, Record 159 city: nanortalik not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 160, City Name: bluff.
# Oops, Record 160 city: bluff not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 161, City Name: sitka.
# Oops, Record 161 city: sitka not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 162, City Name: victor harbor.
# Oops, Record 162 city: victor harbor not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 163, City Name: hithadhoo.
# Oops, Record 163 city: hithadhoo not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 164, City Name: ilulissat.
# Oops, Record 164 city: ilulissat not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 165, City Name: sikasso.
# Oops, Record 165 city: sikasso not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 169, City Name: belushya guba.
# Oops, Record 169 city: belushya guba not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 170, City Name: nouadhibou.
# Oops, Record 170 city: nouadhibou not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 172, City Name: cherskiy.
# Oops, Record 172 city: cherskiy not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 174, City Name: altamira.
# Oops, Record 174 city: altamira not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 175, City Name: kitimat.
# Oops, Record 175 city: kitimat not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 176, City Name: srednekolymsk.
# Oops, Record 176 city: srednekolymsk not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 181, City Name: wajima.
# Oops, Record 181 city: wajima not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 184, City Name: coracora.
# Oops, Record 184 city: coracora not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 185, City Name: tsihombe.
# Oops, Record 185 city: tsihombe not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 187, City Name: forio.
# Oops, Record 187 city: forio not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 192, City Name: zyryanka.
# Oops, Record 192 city: zyryanka not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 193, City Name: whitianga.
# Oops, Record 193 city: whitianga not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 197, City Name: belgrade.
# Oops, Record 197 city: belgrade not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 199, City Name: port blair.
# Oops, Record 199 city: port blair not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 201, City Name: vaini.
# Oops, Record 201 city: vaini not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 202, City Name: san cristobal.
# Oops, Record 202 city: san cristobal not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 206, City Name: pisco.
# Oops, Record 206 city: pisco not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 209, City Name: gaurnadi.
# Oops, Record 209 city: gaurnadi not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 213, City Name: bilibino.
# Oops, Record 213 city: bilibino not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 214, City Name: zhitikara.
# Oops, Record 214 city: zhitikara not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 216, City Name: tasiilaq.
# Oops, Record 216 city: tasiilaq not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 217, City Name: mangai.
# Oops, Record 217 city: mangai not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 218, City Name: praia da vitoria.
# Oops, Record 218 city: praia da vitoria not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 223, City Name: bacolod.
# Oops, Record 223 city: bacolod not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 225, City Name: bogandinskiy.
# Oops, Record 225 city: bogandinskiy not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 227, City Name: mahibadhoo.
# Oops, Record 227 city: mahibadhoo not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 228, City Name: dikson.
# Oops, Record 228 city: dikson not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 230, City Name: rupert.
# Oops, Record 230 city: rupert not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 232, City Name: beloha.
# Oops, Record 232 city: beloha not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 233, City Name: taoudenni.
# Oops, Record 233 city: taoudenni not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 234, City Name: vaitupu.
# Oops, Record 234 city: vaitupu not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 237, City Name: tumannyy.
# Oops, Record 237 city: tumannyy not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 238, City Name: klyuchi.
# Oops, Record 238 city: klyuchi not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 241, City Name: petropavl.
# Oops, Record 241 city: petropavl not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 242, City Name: chokurdakh.
# Oops, Record 242 city: chokurdakh not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 243, City Name: lavrentiya.
# Oops, Record 243 city: lavrentiya not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 244, City Name: norman wells.
# Oops, Record 244 city: norman wells not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 245, City Name: iqaluit.
# Oops, Record 245 city: iqaluit not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 247, City Name: berlevag.
# Oops, Record 247 city: berlevag not found!
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# Processing Record 248, City Name: grand river south east.
# Oops, Record 248 city: grand river south east not found!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-5e730c6be4e4> in <module>
#       4     country_code = row['Country']
#       5     query_url = url + city + ',' + country_code + '&units=' + units + '&APPID=' + api_key
# ----> 6     weather_response = requests.get(query_url)
#       7     weather_json = weather_response.json()
#       8
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
#change all data recieved from openweathermap api to numerical data
city_df['Latitude'] = pd.to_numeric(city_df['Latitude'])
city_df['Longitude'] = pd.to_numeric(city_df['Longitude'])
city_df['Max Temperature (F)'] = pd.to_numeric(city_df['Max Temperature (F)'])
city_df['Humidity (%)'] = pd.to_numeric(city_df['Humidity (%)'])
city_df['Cloudiness (%)'] = pd.to_numeric(city_df['Cloudiness (%)'])
city_df['Wind Speed (mph)'] = pd.to_numeric(city_df['Wind Speed (mph)'])

# %%
# #remove rows and columns with None values
# new_city_df=city_df[city_df['Date'] != ""]
# new_city_df.reset_index(inplace=True)
# del new_city_df['index']
# print("We only have {} cities containing weather information.".format(len(new_city_df)))

# %%
new_city_df=city_df.dropna()
len(new_city_df)

# %%
new_city_df.head()

# %%
a

# %% [markdown]
# ### Export DataFrame to CSV File

# %%
new_city_df.to_csv("weatherpy_data.csv", encoding="utf-8", index=False)

# %% [markdown]
# #  Build scatter plots to showcase the following relationships:
# * Temperature (F) vs. Latitude
# * Humidity (%) vs. Latitude
# * Cloudiness (%) vs. Latitude
# * Wind Speed (mph) vs. Latitude

# %% [markdown]
# ### Temperature (F) vs. Latitude

# %%
#Temperature (F) vs. Latitude
new_city_df.plot(kind="scatter", x="Latitude", y="Max Temperature (F)", grid=True, figsize=(8,8),
              title="Latitude vs Temperature") 
plt.savefig("City Latitude vs Temperature.jpeg")
plt.show()

# %% [markdown]
# #### The plot shows that the cities near the equator have higher temperatures and the cities which are far away from the equator have lower temperature.

# %% [markdown]
# ### Humidity (%) vs. Latitude

# %%
#Humidity (%) vs. Latitude
new_city_df.plot(kind="scatter", x="Latitude", y="Humidity (%)", grid=True, figsize=(8,8),
              title="Latitude vs Humidity") 
plt.savefig("City Latitude vs Humidity.jpeg")
plt.show()

# %% [markdown]
# #### The plot shows that there is no real pattern that can describe the relationship between latitude and humidity

# %% [markdown]
# ### Cloudiness (%) vs. Latitude

# %%
#Cloudiness (%) vs. Latitude
new_city_df.plot(kind="scatter", x="Latitude", y="Cloudiness (%)", grid=True, figsize=(8,8),
              title="Latitude vs Cloudiness") 
plt.savefig("City Latitude vs Cloudiness.jpeg")
plt.show()

# %% [markdown]
# #### The plot shows that there is no real pattern that can describe the relationship between latitude and Cloudiness

# %% [markdown]
# ### Wind Speed (mph) vs. Latitude

# %%
#Wind Speed (mph) vs. Latitude
new_city_df.plot(kind="scatter", x="Latitude", y="Wind Speed (mph)", grid=True, figsize=(8,8),
              title="Latitude vs Wind Speed") 
plt.savefig("City Latitude vs Wind Speed.jpeg")
plt.show()

# %% [markdown]
# #### The plot shows that there is no real pattern that can describe the relationship between latitude and windspeed

# %% [markdown]
# ## Perform linear regression on each relationship
#
# * Northern Hemisphere - Temperature (F) vs. Latitude
# * Southern Hemisphere - Temperature (F) vs. Latitude
# * Northern Hemisphere - Humidity (%) vs. Latitude
# * Southern Hemisphere - Humidity (%) vs. Latitude
# * Northern Hemisphere - Cloudiness (%) vs. Latitude
# * Southern Hemisphere - Cloudiness (%) vs. Latitude
# * Northern Hemisphere - Wind Speed (mph) vs. Latitude
# * Southern Hemisphere - Wind Speed (mph) vs. Latitude

# %%
Northern_Hemisphere=new_city_df[new_city_df['Latitude']>0]
Southern_Hemisphere=new_city_df[new_city_df['Latitude']<0]

# %%
#Northern Hemisphere - Temperature (F) vs. Latitude
x_values = Northern_Hemisphere['Latitude']
y_values = Northern_Hemisphere['Max Temperature (F)']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title("Latitude vs Temperature (F) in Northern Hemisphere")
print(f"Regression line equation is: {line_eq}")
print(f"The r-squared is: {round(rvalue, 2)}")
print("The regression displays a negative correlation.")
print("In the Northern hemisphere, as the cities get closer to the equator, the temperature decreases.")
plt.savefig("Northern Hemisphere - Latitude vs Temperature (F).jpeg")
plt.show()

# %%
#Southern Hemisphere - Temperature (F) vs. Latitude
x_values = Southern_Hemisphere['Latitude']
y_values = Southern_Hemisphere['Max Temperature (F)']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,60),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title("Latitude vs Temperature (F) in Southern Hemisphere")
print(f"Regression line equation is: {line_eq}")
print(f"The r-squared is: {round(rvalue, 2)}")
print("The regression displays a positive correlation.")
print("In the Southern hemisphere, as the cities get closer to the equator, the temperature increases.")
plt.savefig("Southern Hemisphere - Latitude vs Temperature (F).jpeg")
plt.show()

# %%
#Northern Hemisphere - Humidity (%) vs. Latitude
x_values = Northern_Hemisphere['Latitude']
y_values = Northern_Hemisphere['Humidity (%)']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,40),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title("Latitude vs Humidity (%) in Northern Hemisphere")
print(f"The r-squared is: {round(rvalue, 2)}")
print("The regression is generally considered a None or Very weak relationship between latitude and humidity") 
plt.savefig("Northern Hemisphere - Latitude vs Humidity (%).jpeg")
plt.show()

# %%
#Southern Hemisphere - Humidity (%) vs. Latitude
x_values = Southern_Hemisphere['Latitude']
y_values = Southern_Hemisphere['Humidity (%)']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,60),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title("Latitude vs Humidity (%) in Southern Hemisphere")
print(f"The r-squared is: {round(rvalue, 2)}")
print("The regression is generally considered a None or Very weak relationship between latitude and humidity") 
plt.savefig("Southern Hemisphere - Latitude vs Humidity (%).jpeg")
plt.show()

# %%
#Northern Hemisphere - Cloudiness (%) vs. Latitude
x_values = Northern_Hemisphere['Latitude']
y_values = Northern_Hemisphere['Cloudiness (%)']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,25),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title("Latitude vs Cloudiness (%) in Northern Hemisphere")
print(f"The r-squared is: {round(rvalue, 2)}")
print("The regression is generally considered a None or Very weak relationship between latitude and cloudiness") 
plt.savefig("Northern Hemisphere - Latitude vs Cloudiness (%).jpeg")
plt.show()

# %%
#Southern Hemisphere - Cloudiness (%) vs. Latitude
x_values = Southern_Hemisphere['Latitude']
y_values = Southern_Hemisphere['Cloudiness (%)']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,25),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title("Latitude vs Cloudiness (%) in Southern Hemisphere")
print(f"The r-squared is: {round(rvalue, 2)}")
print("Although not obvious, there is a linear relationship between cloundiness and latitude: As latitute increases, cloudiness increases.") 
plt.savefig("Southern Hemisphere - Latitude vs Cloudiness (%).jpeg")
plt.show()

# %%
#Northern Hemisphere - Wind Speed (mph) vs. Latitude
x_values = Northern_Hemisphere['Latitude']
y_values = Northern_Hemisphere['Wind Speed (mph)']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,25),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title("Latitude vs Wind Speed (mph) in Northern Hemisphere")
print(f"The r-squared is: {round(rvalue, 2)}")
print("The regression is generally considered a None or Very weak relationship between latitude and wind speed") 
plt.savefig("Northern Hemisphere - Latitude vs Wind Speed (mph).jpeg")
plt.show()

# %%
#Southern Hemisphere - Wind Speed (mph) vs. Latitude
x_values = Southern_Hemisphere['Latitude']
y_values = Southern_Hemisphere['Wind Speed (mph)']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,25),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title("Latitude vs Wind Speed (mph) in Southern Hemisphere")
print(f"The r-squared is: {round(rvalue, 2)}")
print("The regression is generally considered a None or Very weak relationship between latitude and wind speed") 
plt.savefig("Southern Hemisphere - Latitude vs Wind Speed (mph).jpeg")
plt.show()

# %% [markdown]
# # Observations

# %% [markdown]
# * Temperature correlates well with the latitude. As latitude moves away from equator, temperature decreases
# * It seems that there is no relationship between latitude and humidity.
# * Even though there is very low correlation between latitude and wind speed, wind speed tends to be higher near arctic and antarctic
